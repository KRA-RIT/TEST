# %%
RAW_DATA = r'C:\Users\411792\Desktop\HDC\ALL.csv'
out_path = r'C:\Users\411792\Desktop\HDC\ALL.csv'

# %%
import xlsxwriter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import openpyxl
from openpyxl.chart import BarChart3D,Reference

# %%
df = pd.read_csv(RAW_DATA)

x = np.arange(len(df['WW']))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 0.4, df['Niran'], width, label='Niran')
rects2 = ax.bar(x - 0.2, df['Peerayoot'], width, label='Peerayoot')
rects3 = ax.bar(x + 0, df['Chatchana'], width, label='Chatchana')
rects4 = ax.bar(x + 0.2, df['Pakyada'], width, label='Pakyada')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('%HD submission')
ax.set_title('Niran group: %HD Submission by Manager')
ax.set_xticks(x)
ax.set_xticklabels(df['WW'])
ax.legend(loc ="lower left")

#ax.bar_label(rects1, padding = 3)
#ax.bar_label(rects2, padding = 3)
#ax.bar_label(rects3, padding = 3)
#ax.bar_label(rects4, padding = 3)

fig.tight_layout()

plt.show()
